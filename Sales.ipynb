# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv('Sales.csv')

# Display the first few rows of the dataset
print(data.head())
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
# Check for missing values
print(data.isnull().sum())

# Assuming no missing values, or you can handle them if there are any
data = data.fillna(data.mean())

# Display the cleaned dataset
print(data.head())
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
# Define the features and target variable
X = data[['TV', 'Radio', 'Newspaper']]
y = data['Sales']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Train and evaluate the models
results = {}
predictions = {}

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    mae = mean_absolute_error(y_test, y_pred)
    rmse = mean_squared_error(y_test, y_pred, squared=False)

    results[name] = {'MAE': mae, 'RMSE': rmse}
    predictions[name] = y_pred

# Display the results
for model_name, metrics in results.items():
    print(f'{model_name}:')
    print(f'  MAE: {metrics["MAE"]}')
    print(f'  RMSE: {metrics["RMSE"]}')
    print()
# Out:
# Linear Regression:
#   MAE: 1.2748262109549338
#   RMSE: 1.7052146229349223
#
# Decision Tree Regression:
#   MAE: 1.24
#   RMSE: 1.8444511378727275
#
# Random Forest Regression:
#   MAE: 0.9179999999999993
#   RMSE: 1.1989298770153327
#
# Gradient Boosting Regression:
#   MAE: 0.830119958670547
#   RMSE: 1.1203843000922045

# %%
# Visualize the results
results_df = pd.DataFrame(results).T
results_df.plot(kind='bar', figsize=(10, 6))
plt.title('Model Performance Comparison')
plt.ylabel('Error')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualize the predictions vs actual sales
plt.figure(figsize=(14, 7))
plt.plot(y_test.values, label='Actual Sales', marker='o')

for name, y_pred in predictions.items():
    plt.plot(y_pred, label=f'Predicted Sales ({name})', linestyle='--', marker='x')

plt.title('Actual Sales vs Predicted Sales')
plt.xlabel('Test Data Points')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
# Assuming Gradient Boosting Regression performed the best
best_model = GradientBoostingRegressor(random_state=42)
best_model.fit(X_train, y_train)

# Load new data for prediction
new_data = pd.DataFrame({
    'TV': [100, 150, 200],
    'Radio': [20, 25, 30],
    'Newspaper': [10, 15, 20]
})

# Predict future sales
future_sales = best_model.predict(new_data)

print(future_sales)
# Out:
# [13.29197772 13.82827478 18.62737145]
